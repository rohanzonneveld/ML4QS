# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# load data
acc = pd.read_csv('data/phone/20230608/Linear Accelerometer.csv')
gyro = pd.read_csv('data/phone/20230608/Gyroscope.csv')
baro = pd.read_csv('data/phone/20230608/Barometer.csv')
loc = pd.read_csv('data/phone/20230608/Location.csv')

print("acc: ", len(acc))
print("gyro: ", len(gyro))
print("baro" , len(baro))
print("loc ", len(loc))
# Out:
# acc:  203082
# gyro:  203082
# baro 2138
# loc  1129

# %%
active_range = slice(800, 1860)

baroplot = baro[active_range].plot(x='Time (s)', title="Barometer", figsize=(20, 5))
baroplot.set_ylabel("hectoPascal (hPa)")

# %%
# plot gyroscope data
